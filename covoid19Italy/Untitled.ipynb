# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as pl
pl.style.use('seaborn-whitegrid')
pl.rcParams['figure.figsize']=10,8

# %%
data=pd.read_csv('covid19_italy_region.csv',parse_dates=True)

# %%
data.head()
# Out:
#    SNo                 Date Country  RegionCode    RegionName   Latitude  \
# 0    0  2020-02-24T18:00:00     ITA          13       Abruzzo  42.351222
# 1    1  2020-02-24T18:00:00     ITA          17    Basilicata  40.639471
# 2    2  2020-02-24T18:00:00     ITA           4  P.A. Bolzano  46.499335
# 3    3  2020-02-24T18:00:00     ITA          18      Calabria  38.905976
# 4    4  2020-02-24T18:00:00     ITA          15      Campania  40.839566
#
#    Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 0  13.398438                     0                      0
# 1  15.805148                     0                      0
# 2  11.356624                     0                      0
# 3  16.594402                     0                      0
# 4  14.250850                     0                      0
#
#    TotalHospitalizedPatients  HomeConfinement  CurrentPositiveCases  \
# 0                          0                0                     0
# ...

# %%
data1=pd.read_csv('covid19_italy_province.csv',parse_dates=True)

# %%
data1.head()
# Out:
#    SNo                 Date Country  RegionCode RegionName  ProvinceCode  \
# 0    0  2020-02-24T18:00:00     ITA          13    Abruzzo            69
# 1    1  2020-02-24T18:00:00     ITA          13    Abruzzo            66
# 2    2  2020-02-24T18:00:00     ITA          13    Abruzzo            68
# 3    3  2020-02-24T18:00:00     ITA          13    Abruzzo            67
# 4    4  2020-02-24T18:00:00     ITA          13    Abruzzo           979
#
#                            ProvinceName ProvinceAbbreviation   Latitude  \
# 0                                Chieti                   CH  42.351032
# 1                              L'Aquila                   AQ  42.351222
# 2                               Pescara                   PE  42.464584
# 3                                Teramo                   TE  42.658918
# 4  In fase di definizione/aggiornamento                  NaN   0.000000
#
#    Longitude  TotalPositiveCases
# 0  14.167546                   0
# ...

# %%
data.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
data1.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'ProvinceCode',
#        'ProvinceName', 'ProvinceAbbreviation', 'Latitude', 'Longitude',
#        'TotalPositiveCases'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# SNo                             0
# Date                            0
# Country                         0
# RegionCode                      0
# RegionName                      0
# Latitude                        0
# Longitude                       0
# HospitalizedPatients            0
# IntensiveCarePatients           0
# TotalHospitalizedPatients       0
# HomeConfinement                 0
# CurrentPositiveCases            0
# NewPositiveCases                0
# Recovered                       0
# Deaths                          0
# TotalPositiveCases              0
# TestsPerformed               1155
# dtype: int64

# %%
# data=data.drop(['TestsPerformed'],axis=1)

# %%
data.isnull().sum()
# Out:
# SNo                             0
# Date                            0
# Country                         0
# RegionCode                      0
# RegionName                      0
# Latitude                        0
# Longitude                       0
# HospitalizedPatients            0
# IntensiveCarePatients           0
# TotalHospitalizedPatients       0
# HomeConfinement                 0
# CurrentPositiveCases            0
# NewPositiveCases                0
# Recovered                       0
# Deaths                          0
# TotalPositiveCases              0
# TestsPerformed               1155
# dtype: int64

# %%
data['TestsPerformed']
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 1381    106150.0
# 1382     20944.0
# 1383     24079.0
# 1384      5337.0
# 1385    200737.0
# Name: TestsPerformed, Length: 1386, dtype: float64

# %%
sns.relplot(y="TotalPositiveCases",x="Recovered", data=data)

# %%
sns.relplot(data=data,y='TotalPositiveCases',x='HospitalizedPatients',hue='Recovered')

# %%
sns.relplot(y="TotalPositiveCases",x="CurrentPositiveCases", data=data)

# %%
data['TotalPositiveCases'].max(),data['Recovered'].max()
# Out:
# (75134, 25333)

# %%
data.tail().T
# Out:
#                                           1381                 1382  \
# SNo                                       1381                 1382
# Date                       2020-04-29T17:00:00  2020-04-29T17:00:00
# Country                                    ITA                  ITA
# RegionCode                                   9                    4
# RegionName                             Toscana          P.A. Trento
# Latitude                               43.7692              46.0689
# Longitude                              11.2559              11.1212
# HospitalizedPatients                       576                  165
# IntensiveCarePatients                      139                   22
# TotalHospitalizedPatients                  715                  187
# HomeConfinement                           4948                 1276
# CurrentPositiveCases                      5663                 1463
# NewPositiveCases                            61                   44
# ...

# %%
sns.pairplot(data)

# %%
sns.relplot(y="Recovered",x="HomeConfinement", data=data,kind='line')

# %%
sns.catplot(y="TotalPositiveCases",x="Recovered",data=data)

# %%
data
# Out:
#        SNo                 Date Country  RegionCode     RegionName   Latitude  \
# 0        0  2020-02-24T18:00:00     ITA          13        Abruzzo  42.351222
# 1        1  2020-02-24T18:00:00     ITA          17     Basilicata  40.639471
# 2        2  2020-02-24T18:00:00     ITA           4   P.A. Bolzano  46.499335
# 3        3  2020-02-24T18:00:00     ITA          18       Calabria  38.905976
# 4        4  2020-02-24T18:00:00     ITA          15       Campania  40.839566
# ...    ...                  ...     ...         ...            ...        ...
# 1381  1381  2020-04-29T17:00:00     ITA           9        Toscana  43.769231
# 1382  1382  2020-04-29T17:00:00     ITA           4    P.A. Trento  46.068935
# 1383  1383  2020-04-29T17:00:00     ITA          10         Umbria  43.106758
# 1384  1384  2020-04-29T17:00:00     ITA           2  Valle d'Aosta  45.737503
# 1385  1385  2020-04-29T17:00:00     ITA           5         Veneto  45.434905
#
# ...

# %%
sns.distplot(data['HospitalizedPatients'])

# %%
sns.countplot(data['RegionName'])
pl.xticks(rotation=90)
pl.show()

# %%
data.groupby('RegionName')['HospitalizedPatients'].sum().sort_values().plot(kind='bar')

# %%
data.groupby('RegionName')['IntensiveCarePatients'].sum().sort_values().plot(kind='bar')

# %%
data.groupby('RegionName')['CurrentPositiveCases'].sum().sort_values().plot(kind='bar')

# %%
data.groupby('RegionName')['NewPositiveCases'].sum().sort_values().plot(kind='bar')

# %%
data.groupby('RegionName')['Deaths'].sum().sort_values().plot(kind='bar')

# %%
data.groupby('RegionName')['Recovered'].sum().sort_values().plot(kind='bar')

# %%
data.groupby('RegionName')['TotalPositiveCases'].sum().sort_values().plot(kind='bar')

# %%
data.groupby('RegionName')['TestsPerformed'].sum().sort_values().plot(kind='bar')

# %%
data.groupby('RegionName')['TestsPerformed'].sum().sort_values().plot(kind='line',label='TestsPerformed')
data.groupby('RegionName')['HospitalizedPatients'].sum().sort_values().plot(kind='line',label='HospitalizedPatients')
data.groupby('RegionName')['IntensiveCarePatients'].sum().sort_values().plot(kind='line',label='IntensiveCarePatients')
data.groupby('RegionName')['CurrentPositiveCases'].sum().sort_values().plot(kind='line',label='CurrentPositiveCases')
data.groupby('RegionName')['NewPositiveCases'].sum().sort_values().plot(kind='line',label='NewPositiveCases')
data.groupby('RegionName')['Recovered'].sum().sort_values().plot(kind='line',label='Recovered')
data.groupby('RegionName')['Deaths'].sum().sort_values().plot(kind='line',label='Deaths')
pl.legend()

# %%
data.groupby('RegionName')['Recovered'].sum().sort_values().plot(kind='line',label='Recovered')
data.groupby('RegionName')['Deaths'].sum().sort_values().plot(kind='line',label='Deaths')
pl.legend()
