# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl
import seaborn as sns
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
bottle=pd.read_csv('/Users/rissu/bottle.csv')
cast=pd.read_csv('/Users/rissu/cast.csv')
# Out:
# C:\Users\rissu\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (47,73) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\rissu\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (40,41,44,45,46,47) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
bottle.head()
# Out:
#    Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 0        1        1  054.0 056.0  19-4903CR-HY-060-0930-05400560-0000A-3
# 1        1        2  054.0 056.0  19-4903CR-HY-060-0930-05400560-0008A-3
# 2        1        3  054.0 056.0  19-4903CR-HY-060-0930-05400560-0010A-7
# 3        1        4  054.0 056.0  19-4903CR-HY-060-0930-05400560-0019A-3
# 4        1        5  054.0 056.0  19-4903CR-HY-060-0930-05400560-0020A-7
#
#    Depthm  T_degC  Salnty  O2ml_L  STheta  O2Sat  Oxy_µmol/Kg  BtlNum  RecInd  \
# 0       0   10.50  33.440     NaN  25.649    NaN          NaN     NaN       3
# 1       8   10.46  33.440     NaN  25.656    NaN          NaN     NaN       3
# 2      10   10.46  33.437     NaN  25.654    NaN          NaN     NaN       7
# 3      19   10.45  33.420     NaN  25.643    NaN          NaN     NaN       3
# 4      20   10.45  33.421     NaN  25.643    NaN          NaN     NaN       7
#
# ...

# %%
cast.head()
# Out:
#    Cst_Cnt          Cruise_ID  Cruise        Cruz_Sta  DbSta_ID  \
# 0        1  1949-03-01-C-31CR  194903  19490305400560   5400560
# 1        2  1949-03-01-C-31CR  194903  19490305200750   5200750
# 2        3  1949-03-01-C-31CR  194903  19490305100850   5100850
# 3        4  1949-03-01-C-31CR  194903  19490305000950   5000950
# 4        5  1949-03-01-C-31CR  194903  19490305001040   5001040
#
#                           Cast_ID       Sta_ID  Quarter Sta_Code  Distance  \
# 0  19-4903CR-HY-060-0930-05400560  054.0 056.0        1      NST       NaN
# 1  19-4903CR-HY-060-2112-05200750  052.0 075.0        1      NST       NaN
# 2  19-4903CR-HY-061-0354-05100850  051.0 085.0        1      NST       NaN
# 3  19-4903CR-HY-061-1042-05000950  050.0 095.0        1      NST       NaN
# 4  19-4903CR-HY-061-1706-05001040  050.0 104.0        1      NST       NaN
#
#          Date  Year  Month  Julian_Date  Julian_Day      Time    Lat_Dec  \
# ...

# %%
sns.heatmap(bottle.isnull())

# %%
bottle.shape,cast.shape
# Out:
# ((864863, 74), (34404, 61))

# %%
a=bottle.isnull().sum()>100000

# %%
drop=a[a==True]

# %%
x=bottle[drop.index]

# %%
x.shape
# Out:
# (864863, 50)

# %%
sns.heatmap(x.isnull())

# %%
x.isnull().sum()
# Out:
# O2ml_L                 168662
# O2Sat                  203589
# Oxy_µmol/Kg            203595
# BtlNum                 746196
# T_qual                 841736
# S_qual                 789949
# P_qual                 191108
# O_qual                 680187
# SThtaq                 799040
# O2Satq                 647066
# ChlorA                 639591
# Chlqua                 225697
# Phaeop                 639592
# Phaqua                 225693
# PO4uM                  451546
# PO4q                   413077
# SiO3uM                 510772
# SiO3qu                 353997
# NO2uM                  527287
# NO2q                   335389
# NO3uM                  527460
# NO3q                   334930
# NH3uM                  799901
# C14As1                 850431
# C14A1p                 852103
# C14As2                 850449
# C14A2p                 852121
# DarkAs                 842214
# DarkAp                 844406
# MeanAs                 842213
# MeanAp                 844406
# ...

# %%
data1=bottle.copy()

# %%
data1.drop(x.columns,axis=1,inplace=True)

# %%
data1.isnull().sum()
# Out:
# Cst_Cnt           0
# Btl_Cnt           0
# Sta_ID            0
# Depth_ID          0
# Depthm            0
# T_degC        10963
# Salnty        47354
# STheta        52689
# RecInd            0
# T_prec        10963
# S_prec        47354
# NH3q          56564
# C14A1q        16258
# C14A2q        16240
# DarkAq        24423
# MeanAq        24424
# R_Depth           0
# R_TEMP        10963
# R_POTEMP      46047
# R_SALINITY    47354
# R_SIGMA       52856
# R_SVA         52771
# R_DYNHT       46657
# R_PRES            0
# dtype: int64

# %%
data1.head()
# Out:
#    Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 0        1        1  054.0 056.0  19-4903CR-HY-060-0930-05400560-0000A-3
# 1        1        2  054.0 056.0  19-4903CR-HY-060-0930-05400560-0008A-3
# 2        1        3  054.0 056.0  19-4903CR-HY-060-0930-05400560-0010A-7
# 3        1        4  054.0 056.0  19-4903CR-HY-060-0930-05400560-0019A-3
# 4        1        5  054.0 056.0  19-4903CR-HY-060-0930-05400560-0020A-7
#
#    Depthm  T_degC  Salnty  STheta  RecInd  T_prec  S_prec  NH3q  C14A1q  \
# 0       0   10.50  33.440  25.649       3     1.0     2.0   9.0     9.0
# 1       8   10.46  33.440  25.656       3     2.0     2.0   9.0     9.0
# 2      10   10.46  33.437  25.654       7     2.0     3.0   9.0     9.0
# 3      19   10.45  33.420  25.643       3     2.0     2.0   9.0     9.0
# 4      20   10.45  33.421  25.643       7     2.0     3.0   9.0     9.0
#
#    C14A2q  DarkAq  MeanAq  R_Depth  R_TEMP  R_POTEMP  R_SALINITY  R_SIGMA  \
# ...

# %%
data1.groupby('Sta_ID')['Sta_ID'].count()
# Out:
# Sta_ID
# 001.0 168.0       37
# 001.0 263.5       55
# 002.0 065.7       34
# 004.0 086.0       38
# 004.0 088.0      116
# 004.0 099.0       46
# 004.0 104.0       38
# 004.0 121.0      143
# 004.0 138.5       38
# 004.0 155.7       19
# 004.0 156.5       19
# 004.0 172.7       19
# 004.0 173.0       19
# 004.0 188.5       65
# 004.0 190.0       90
# 004.0 209.7       19
# 004.0 227.0       19
# 004.0 263.7      180
# 005.0 204.0       46
# 005.0 333.0      158
# 006.0 079.0      124
# 006.7 134.0       39
# 006.7 305.5       68
# 008.0 070.0       86
# 008.0 114.0       36
# 009.0 062.0       54
# 009.5 192.0       19
# 010.0 010.0       76
# 010.0 020.0      150
# 010.0 030.0       38
# 010.0 039.0       46
# 010.0 040.0       38
# 010.0 050.0       38
# 010.0 060.0       74
# 010.0 068.0      108
# 010.0 080.0       56
# 010.0 099.0       37
# 011.0 053.0       85
# 012.0 172.0       38
# 012.7 085.0       36
# 013.0 173.7       19
# 013.3 044.0       55
# 013.3 274.0       38
# ...

# %%
data1.shape
# Out:
# (864863, 24)

# %%
data1.columns
# Out:
# Index(['Cst_Cnt', 'Btl_Cnt', 'Sta_ID', 'Depth_ID', 'Depthm', 'T_degC',
#        'Salnty', 'STheta', 'RecInd', 'T_prec', 'S_prec', 'NH3q', 'C14A1q',
#        'C14A2q', 'DarkAq', 'MeanAq', 'R_Depth', 'R_TEMP', 'R_POTEMP',
#        'R_SALINITY', 'R_SIGMA', 'R_SVA', 'R_DYNHT', 'R_PRES'],
#       dtype='object')

# %%
data2=data1.copy()
data2.drop(['Sta_ID','Depth_ID'],axis=1,inplace=True)

# %%
data2.columns
# Out:
# Index(['Cst_Cnt', 'Btl_Cnt', 'Depthm', 'T_degC', 'Salnty', 'STheta', 'RecInd',
#        'T_prec', 'S_prec', 'NH3q', 'C14A1q', 'C14A2q', 'DarkAq', 'MeanAq',
#        'R_Depth', 'R_TEMP', 'R_POTEMP', 'R_SALINITY', 'R_SIGMA', 'R_SVA',
#        'R_DYNHT', 'R_PRES'],
#       dtype='object')

# %%
for cols in data2.columns:
    pl.plot(data2[cols])
    pl.title(cols)
    pl.show()

# %%
pl.scatter(data2.Cst_Cnt,data2.R_SALINITY)

# %%
calcofi=bottle.loc[:,'Depthm':'O2Satq']

# %%
calcofi.isnull().sum()
# Out:
# Depthm              0
# T_degC          10963
# Salnty          47354
# O2ml_L         168662
# STheta          52689
# O2Sat          203589
# Oxy_µmol/Kg    203595
# BtlNum         746196
# RecInd              0
# T_prec          10963
# T_qual         841736
# S_prec          47354
# S_qual         789949
# P_qual         191108
# O_qual         680187
# SThtaq         799040
# O2Satq         647066
# dtype: int64

# %%
fig,ax=pl.subplots(1,2)
sns.distplot(calcofi.T_degC.dropna(),ax=ax[0])
ax[0].set_title('Dropna')
sns.distplot(calcofi.T_degC.fillna(calcofi.T_degC.mean()),ax=ax[1])
ax[1].set_title("Fillna with mean")
# Out:
# Text(0.5, 1.0, 'Fillna with mean')

# %%
fig, ax=plt.subplots(1,2)
sns.distplot(calcofi.O2Satq.dropna(), ax=ax[0],kde=False)
ax[0].set_title("Dropna")
sns.distplot(calcofi.O2Satq.fillna(calcofi.O2Satq.mean()), ax=ax[1],kde=False)
ax[1].set_title("Fillna mean")
# Out:
# Text(0.5, 1.0, 'Fillna mean')

# %%
from scipy import stats

# %%
normalized_ox_dropna=stats.boxcox(calcofi.O2Satq.dropna())[0]
normalized_ox_fillna=stats.boxcox(calcofi.O2Satq.fillna(calcofi.O2Satq.mean()))[0]
fig,ax=pl.subplots(1,2)
sns.distplot(normalized_ox_dropna,ax=ax[0],kde=False)
ax[0].set_title("Norm Dropna")
sns.distplot(normalized_ox_fillna,ax=ax[1],kde=False)
ax[1].set_title("Norm Fillna")
# Out:
# Text(0.5, 1.0, 'Norm Fillna')

# %%
selected=bottle[['Salnty','T_degC']]
selected.columns=['Sal','Temp']

# %%
# sns.lmplot(x='Sal',y='Temp',data=selected,order=2,ci=None)

# %% [markdown]
# # Salinity vs Water temperature

# %%
pl.figure(figsize=(13, 9))
pl.scatter(selected.Sal,selected.Temp)
pl.xlabel('Salinity')
pl.ylabel('Temperature')
pl.title("Salinity_temp")
pl.show()

# %%
new_salt_degree=selected[:][:750]
len(new_salt_degree)
# Out:
# 750

# %%
new_salt_degree['Sal'].isna().value_counts()
new_salt_degree['Temp'].isna().value_counts()
new_salt_degree=new_salt_degree.dropna(axis=0,how='any')

# %%
a=new_salt_degree.copy()

# %%
sns.heatmap(a.isnull())

# %%
a=a.drop_duplicates()

# %%
pl.figure(figsize=(10,10))
pl.scatter(a['Sal'],a['Temp'])
pl.xlabel("Salinity")
pl.ylabel("Temperature")
pl.title("Salinity_temp")
pl.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
X=a.iloc[:,:-1].values
y=a.iloc[:,-1].values

# %%
reg=LinearRegression()
reg.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pl.figure(figsize=(10,8))
a=np.arange(32.6,35)
pl.scatter(X,y)
pl.plot(a,reg.coef_*a+reg.intercept_,c='r')

# %%
reg.score(X,y)
# Out:
# 0.7928197218730882

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pol=PolynomialFeatures(degree=3)
X_pol=pol.fit_transform(X)
pol.fit(X_pol,y)
reg=LinearRegression()
reg.fit(X_pol,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.score(X_pol,y)
# Out:
# 0.8799227082502605

# %%
x_grid = np.arange(min(X), max(X), 0.1)
x_grid = x_grid.reshape(-1,1)
pl.scatter(X,y,s=65)
pl.plot(x_grid,reg.predict(pol.fit_transform(x_grid)) , color='red', linewidth = '6')
pl.xlabel('Slt',fontsize=25)
pl.ylabel('Temp',fontsize=25)
pl.title('salt degerlerine gore temp tahmin gosterimi',fontsize=25)
pl.show()

# %%
x_grid = np.arange(min(X), max(X), 0.1).reshape(-1,1)
x_grid
# Out:
# array([[32.63],
#        [32.73],
#        [32.83],
#        [32.93],
#        [33.03],
#        [33.13],
#        [33.23],
#        [33.33],
#        [33.43],
#        [33.53],
#        [33.63],
#        [33.73],
#        [33.83],
#        [33.93],
#        [34.03],
#        [34.13],
#        [34.23],
#        [34.33],
#        [34.43]])

# %%
pol.fit_transform(x_grid)
# Out:
# array([[1.00000000e+00, 3.26300000e+01, 1.06471690e+03, 3.47417124e+04],
#        [1.00000000e+00, 3.27300000e+01, 1.07125290e+03, 3.50621074e+04],
#        [1.00000000e+00, 3.28300000e+01, 1.07780890e+03, 3.53844662e+04],
#        [1.00000000e+00, 3.29300000e+01, 1.08438490e+03, 3.57087948e+04],
#        [1.00000000e+00, 3.30300000e+01, 1.09098090e+03, 3.60350991e+04],
#        [1.00000000e+00, 3.31300000e+01, 1.09759690e+03, 3.63633853e+04],
#        [1.00000000e+00, 3.32300000e+01, 1.10423290e+03, 3.66936593e+04],
#        [1.00000000e+00, 3.33300000e+01, 1.11088890e+03, 3.70259270e+04],
#        [1.00000000e+00, 3.34300000e+01, 1.11756490e+03, 3.73601946e+04],
#        [1.00000000e+00, 3.35300000e+01, 1.12426090e+03, 3.76964680e+04],
#        [1.00000000e+00, 3.36300000e+01, 1.13097690e+03, 3.80347531e+04],
#        [1.00000000e+00, 3.37300000e+01, 1.13771290e+03, 3.83750561e+04],
#        [1.00000000e+00, 3.38300000e+01, 1.14446890e+03, 3.87173829e+04],
# ...

# %% [markdown]
# Numerical Datas

# %%
bottle.describe()
# Out:
#              Cst_Cnt        Btl_Cnt         Depthm         T_degC  \
# count  864863.000000  864863.000000  864863.000000  853900.000000
# mean    17138.790958  432432.000000     226.831951      10.799677
# std     10240.949817  249664.587267     316.050259       4.243825
# min         1.000000       1.000000       0.000000       1.440000
# 25%      8269.000000  216216.500000      46.000000       7.680000
# 50%     16848.000000  432432.000000     125.000000      10.060000
# 75%     26557.000000  648647.500000     300.000000      13.880000
# max     34404.000000  864863.000000    5351.000000      31.140000
#
#               Salnty         O2ml_L         STheta          O2Sat  \
# count  817509.000000  696201.000000  812174.000000  661274.000000
# mean       33.840350       3.392468      25.819394      57.103779
# std         0.461843       2.073256       1.167787      37.094137
# min        28.431000      -0.010000      20.934000      -0.100000
# ...

# %% [markdown]
# Categorical Datas

# %%
bottle.describe(include='O')
# Out:
#              Sta_ID                                Depth_ID  \
# count        864863                                  864863
# unique         2634                                  864850
# top     090.0 045.0  20-16045S-MX-110-2018-06330900-0010A-3
# freq          10043                                       2
#
#                      IncTim                                DIC Quality Comment
# count                 14437                                                 55
# unique                  199                                                 37
# top     12/30/1899 05:45:00  CTD Bottle Misfire; DIC sample compromised.  C...
# freq                    325                                                  9

# %%
bottle[['T_degC','Salnty']].describe()
# Out:
#               T_degC         Salnty
# count  853900.000000  817509.000000
# mean       10.799677      33.840350
# std         4.243825       0.461843
# min         1.440000      28.431000
# 25%         7.680000      33.488000
# 50%        10.060000      33.863000
# 75%        13.880000      34.196900
# max        31.140000      37.034000

# %%
nulls=bottle.isnull().sum().sort_values(ascending=False)
prcnt=round(nulls/len(bottle)*100,2)
df_null=pd.DataFrame(columns=['Attr','Total','Percent'])
df_null.Attr=nulls.index
df_null.Total=nulls.values
df_null.Percent=prcnt.values
df_null
# Out:
#                    Attr   Total  Percent
# 0                   pH2  864853   100.00
# 1   DIC Quality Comment  864808    99.99
# 2                   pH1  864779    99.99
# 3                  DIC2  864639    99.97
# 4                   TA2  864629    99.97
# 5                  DIC1  862864    99.77
# 6                   TA1  862779    99.76
# 7                C14A2p  852121    98.53
# 8                C14A1p  852103    98.52
# 9                C14As2  850449    98.33
# 10               C14As1  850431    98.33
# 11               IncTim  850426    98.33
# 12               LightP  846212    97.84
# 13               DarkAp  844406    97.63
# 14               MeanAp  844406    97.63
# 15               DarkAs  842214    97.38
# 16               MeanAs  842213    97.38
# 17               T_qual  841736    97.33
# 18                NH3uM  799901    92.49
# 19                R_NH4  799881    92.49
# 20               SThtaq  799040    92.39
# 21               S_qual  789949    91.34
# ...

# %%
df=bottle.copy()
for i in df_null.Attr[df_null['Percent']>30]:
    df=df.drop(i,axis=1)

# %%
df.head()
# Out:
#    Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 0        1        1  054.0 056.0  19-4903CR-HY-060-0930-05400560-0000A-3
# 1        1        2  054.0 056.0  19-4903CR-HY-060-0930-05400560-0008A-3
# 2        1        3  054.0 056.0  19-4903CR-HY-060-0930-05400560-0010A-7
# 3        1        4  054.0 056.0  19-4903CR-HY-060-0930-05400560-0019A-3
# 4        1        5  054.0 056.0  19-4903CR-HY-060-0930-05400560-0020A-7
#
#    Depthm  T_degC  Salnty  O2ml_L  STheta  O2Sat  Oxy_µmol/Kg  RecInd  T_prec  \
# 0       0   10.50  33.440     NaN  25.649    NaN          NaN       3     1.0
# 1       8   10.46  33.440     NaN  25.656    NaN          NaN       3     2.0
# 2      10   10.46  33.437     NaN  25.654    NaN          NaN       7     2.0
# 3      19   10.45  33.420     NaN  25.643    NaN          NaN       3     2.0
# 4      20   10.45  33.421     NaN  25.643    NaN          NaN       7     2.0
#
# ...

# %%
for i in df.columns:
    if df[i].isnull().sum()>0:
        df[i].fillna(df[i].mode().mean(),inplace=True)

# %%
sns.heatmap(df.isnull())

# %%
nulls=df.isnull().sum().sort_values(ascending=False)
prcnt=round(nulls/len(bottle)*100,2)
df_null=pd.DataFrame(columns=['Attr','Total','Percent'])
df_null.Attr=nulls.index
df_null.Total=nulls.values
df_null.Percent=prcnt.values
df_null
# Out:
#            Attr  Total  Percent
# 0        R_PRES      0      0.0
# 1       R_O2Sat      0      0.0
# 2       Btl_Cnt      0      0.0
# 3        Sta_ID      0      0.0
# 4      Depth_ID      0      0.0
# 5        Depthm      0      0.0
# 6        T_degC      0      0.0
# 7        Salnty      0      0.0
# 8        O2ml_L      0      0.0
# 9        STheta      0      0.0
# 10        O2Sat      0      0.0
# 11  Oxy_µmol/Kg      0      0.0
# 12       RecInd      0      0.0
# 13       T_prec      0      0.0
# 14       S_prec      0      0.0
# 15       P_qual      0      0.0
# 16       Chlqua      0      0.0
# 17       Phaqua      0      0.0
# 18         NH3q      0      0.0
# 19       C14A1q      0      0.0
# 20       C14A2q      0      0.0
# 21       DarkAq      0      0.0
# 22       MeanAq      0      0.0
# 23      R_Depth      0      0.0
# 24       R_TEMP      0      0.0
# 25     R_POTEMP      0      0.0
# 26   R_SALINITY      0      0.0
# 27      R_SIGMA      0      0.0
# ...

# %%
drop_cols = ['Cst_Cnt', 'Btl_Cnt', 'Sta_ID', 'Depth_ID', 'Depthm']
df_norm = df.drop(drop_cols, axis=1)  #  data for normalization
df_scale = df_norm.copy(deep=True)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler().fit_transform(df_scale)

# %%
df_norm=pd.DataFrame(df_scale,index=df_norm.index,columns=df_norm.columns)

# %%
df_norm.head()
# Out:
#    T_degC  Salnty  O2ml_L  STheta  O2Sat  Oxy_µmol/Kg  RecInd  T_prec  S_prec  \
# 0   10.50  33.440     5.8  25.649  102.4          0.0       3     1.0     2.0
# 1   10.46  33.440     5.8  25.656  102.4          0.0       3     2.0     2.0
# 2   10.46  33.437     5.8  25.654  102.4          0.0       7     2.0     3.0
# 3   10.45  33.420     5.8  25.643  102.4          0.0       3     2.0     2.0
# 4   10.45  33.421     5.8  25.643  102.4          0.0       7     2.0     3.0
#
#    P_qual  Chlqua  Phaqua  NH3q  C14A1q  C14A2q  DarkAq  MeanAq  R_Depth  \
# 0     9.0     9.0     9.0   9.0     9.0     9.0     9.0     9.0      0.0
# 1     9.0     9.0     9.0   9.0     9.0     9.0     9.0     9.0      8.0
# 2     9.0     9.0     9.0   9.0     9.0     9.0     9.0     9.0     10.0
# 3     9.0     9.0     9.0   9.0     9.0     9.0     9.0     9.0     19.0
# 4     9.0     9.0     9.0   9.0     9.0     9.0     9.0     9.0     20.0
#
# ...

# %%
df_norm.corr()
# Out:
#                T_degC    Salnty    O2ml_L    STheta     O2Sat  Oxy_µmol/Kg  \
# T_degC       1.000000 -0.474769  0.616164 -0.795829  0.610070     0.580690
# Salnty      -0.474769  1.000000 -0.618206  0.545147 -0.617832    -0.555258
# O2ml_L       0.616164 -0.618206  1.000000 -0.565780  0.935327     0.435235
# STheta      -0.795829  0.545147 -0.565780  1.000000 -0.532845    -0.615536
# O2Sat        0.610070 -0.617832  0.935327 -0.532845  1.000000     0.348604
# Oxy_µmol/Kg  0.580690 -0.555258  0.435235 -0.615536  0.348604     1.000000
# RecInd      -0.065709  0.060568 -0.043050  0.061734 -0.032794    -0.073043
# T_prec      -0.040445 -0.017962  0.078510  0.023830  0.079487    -0.104462
# S_prec      -0.043133 -0.096793 -0.146127  0.035440 -0.130219     0.197117
# P_qual      -0.000530  0.001892 -0.001069  0.000918 -0.000882    -0.001544
# Chlqua      -0.003889  0.005139 -0.002963  0.004402 -0.001899    -0.008381
# ...

# %%
for i in df_norm.columns.tolist():
    if df_norm[i].mode()[0]==0.0:
        print(' - ',i,df_norm[i].mode()[0])
        df_norm=df_norm.drop(i,axis=1)
# Out:
#  -  Oxy_µmol/Kg 0.0
#  -  R_DYNHT 0.0

# %%
df['Salnty'].mode()
df_corr=pd.DataFrame(columns=['Attributes','Correlation'])
df_corr.Attributes=df_norm.corr()['Salnty'].sort_values(ascending=False).index
df_corr.Correlation=df_norm.corr()['Salnty'].sort_values(ascending=False).values

# %%
df_corr.head()
# Out:
#    Attributes  Correlation
# 0      Salnty     1.000000
# 1  R_SALINITY     0.997472
# 2     R_SIGMA     0.569549
# 3      STheta     0.545147
# 4     R_Depth     0.529287

# %%
plot_attr = ['R_DYNHT', 'R_SIGMA', 'R_Depth', 'RecInd', 'NH3q',  'T_prec', 'T_degC', 'R_POTEMP', 'O2ml_L']
plot_attr
# Out:
# ['R_DYNHT',
#  'R_SIGMA',
#  'R_Depth',
#  'RecInd',
#  'NH3q',
#  'T_prec',
#  'T_degC',
#  'R_POTEMP',
#  'O2ml_L']

# %%
for i in plot_attr:
    if plot_attr[0]==i:
        df_plot=df_corr[df_corr.Attributes==i]
    else:
        df_plot=df_plot.append(df_corr[df_corr.Attributes==i])
df_plot
# Out:
#    Attributes  Correlation
# 2     R_SIGMA     0.569549
# 4     R_Depth     0.529287
# 6      RecInd     0.060568
# 7        NH3q     0.018628
# 15     T_prec    -0.017962
# 17     T_degC    -0.474769
# 19   R_POTEMP    -0.487599
# 22     O2ml_L    -0.618206

# %%
pl.figure(figsize=(8,6))
pl.xlim([32,36])
pl.title('Salinity Distribution (g/Kg)',fontsize=14)
sns.distplot(df['Salnty'],color='darkgreen')

# %%
bottle['Year']=((bottle['Depth_ID'].str.split('-',expand=True)[0])+(bottle['Depth_ID'].str.split('-',expand=True)[1])).map(lambda x:str(x)[:4])
bottle['Month']=bottle['Depth_ID'].str.split('-',expand=True)[1].map(lambda x: x[2:4])

# %%
fig=pl.figure(figsize=(12,6))
fig.autofmt_xdate()
fig.add_subplot(121)
pl.title("Yearly change in Salinity")
sns.scatterplot(data=bottle,x='Year',y='Salnty')

fig.add_subplot(122)
pl.title("Yearly change in Salinity")
sns.scatterplot(data=bottle,x='Month',y='Salnty')
pl.show()

# %%
df_sample = df_norm.sample(n=int(round(len(df)*.002,0)), random_state=0)
fig=pl.figure(figsize=(14,60))
col=3
row=int(len(df_corr.Attributes)/col)
count=1
for i,j in zip(df_plot.Attributes,df_plot.Correlation):
    fig.add_subplot(row,col,count)
    pl.title('Salinity vs {} (corr={:.4})'.format(i,j))
    pl.xlim(-4,4)
    sns.distplot(df_sample.Salnty)
    sns.distplot(df_sample[i],kde=False)
    count+=1

# %%
fig=pl.figure(figsize=(14,60))
col=3
row=int(len(df_corr.Attributes)/col)
count=1
for i,j in zip(df_plot.Attributes,df_plot.Correlation):
    fig.add_subplot(row,col,count)
    pl.title('Salinity vs {} (corr={:.4})'.format(i,j))
    sns.regplot(x=i,y='Salnty',data=df_sample,order=2,color='green')
    count+=1
    pl.show()
# Out:
# C:\Users\rissu\anaconda3\lib\site-packages\seaborn\regression.py:251: RankWarning: Polyfit may be poorly conditioned
#   yhat = reg_func(x, y)
# C:\Users\rissu\anaconda3\lib\site-packages\seaborn\algorithms.py:86: RankWarning: Polyfit may be poorly conditioned
#   boot_dist.append(f(*sample, **func_kwargs))
# C:\Users\rissu\anaconda3\lib\site-packages\seaborn\algorithms.py:86: RankWarning: Polyfit may be poorly conditioned
#   boot_dist.append(f(*sample, **func_kwargs))
# C:\Users\rissu\anaconda3\lib\site-packages\seaborn\algorithms.py:86: RankWarning: Polyfit may be poorly conditioned
#   boot_dist.append(f(*sample, **func_kwargs))
# C:\Users\rissu\anaconda3\lib\site-packages\seaborn\algorithms.py:86: RankWarning: Polyfit may be poorly conditioned
#   boot_dist.append(f(*sample, **func_kwargs))
# C:\Users\rissu\anaconda3\lib\site-packages\seaborn\algorithms.py:86: RankWarning: Polyfit may be poorly conditioned
#   boot_dist.append(f(*sample, **func_kwargs))
# ...
