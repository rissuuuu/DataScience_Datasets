# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pl
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.svm import SVC
from sklearn.cluster import KMeans

# %%
df=pd.read_excel('driver.xlsx')

# %%
df.head()
# Out:
#            id  mean_dist_day  mean_over_speed_perc
# 0  3423311935          71.24                    28
# 1  3423313212          52.53                    25
# 2  3423313724          64.54                    27
# 3  3423311373          55.69                    22
# 4  3423310999          54.58                    25

# %%
sns.distplot(df['mean_dist_day'])

# %%
sns.distplot(df['mean_over_speed_perc'])

# %%
sns.jointplot(data=df,x='mean_dist_day',y='mean_over_speed_perc',kind='reg')

# %%
sns.heatmap(df.isnull())

# %%
df.describe()
# Out:
#                  id  mean_dist_day  mean_over_speed_perc
# count  4.000000e+03    4000.000000           4000.000000
# mean   3.423312e+09      76.041523             10.721000
# std    1.154845e+03      53.469563             13.708543
# min    3.423310e+09      15.520000              0.000000
# 25%    3.423311e+09      45.247500              4.000000
# 50%    3.423312e+09      53.330000              6.000000
# 75%    3.423313e+09      65.632500              9.000000
# max    3.423314e+09     244.790000            100.000000

# %%
df.drop('id',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   mean_dist_day         4000 non-null   float64
#  1   mean_over_speed_perc  4000 non-null   int64
# dtypes: float64(1), int64(1)
# memory usage: 62.6 KB

# %%
np.corrcoef([df['mean_dist_day'],df['mean_over_speed_perc']])
# Out:
# array([[1.        , 0.26689676],
#        [0.26689676, 1.        ]])

# %%
df['mean_dist_day'].corr(df['mean_over_speed_perc'])
# Out:
# 0.2668967587681438

# %%
df.plot.box()

# %%
df[df['mean_dist_day']>100]
# Out:
#       mean_dist_day  mean_over_speed_perc
# 3200         179.22                    95
# 3201         192.34                    69
# 3202         140.25                    92
# 3203         184.28                    70
# 3204         200.58                    50
# ...             ...                   ...
# 3995         160.04                    10
# 3996         176.17                     5
# 3997         170.91                    12
# 3998         176.14                     5
# 3999         168.03                     9
#
# [800 rows x 2 columns]

# %%
kmeans=KMeans(n_clusters=6)

# %%
kmeans.fit(df)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=6, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[5.78909097e+01, 5.28611111e+00, 1.01666667e+00],
#        [1.96973385e+02, 1.12061538e+01, 2.46153846e-02],
#        [4.15563670e+01, 5.39130435e+00, 1.01768607e+00],
#        [1.76636768e+02, 7.15353535e+01, 2.00000000e+00],
#        [1.66250718e+02, 1.03936170e+01, 5.31914894e-03],
#        [5.06142184e+01, 3.30620347e+01, 3.00000000e+00]])

# %%
import mglearn

# %%
pl.figure(figsize=(10,8))
mglearn.discrete_scatter(df.iloc[:,0],df.iloc[:,1],kmeans.labels_)
pl.show()

# %%
np.unique(kmeans.labels_,return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  array([1443,  325, 1354,   99,  376,  403], dtype=int64))

# %%
df['clusters']=kmeans.labels_

# %%
sns.lmplot('mean_dist_day','mean_over_speed_perc',data=df,fit_reg=False,
          palette='coolwarm',hue='clusters')
